# %% [markdown]
# # Introduction to Pandas
#
# ![pandas Logo](https://github.com/pandas-dev/pandas/raw/master/web/pandas/static/img/pandas.svg)
#
# ### Questions
# 1. What is Pandas?
# 1. What are the basic Pandas data structures?
# 1. How can I read data into Pandas?
# 1. What are some of the data operations available in Pandas?

# %% [markdown]
# # Pandas Tutorial
#
# ## Read in Tabular Data stored in CSV
#
# ENSO data

# %%
import pandas as pd

# Read in initial data
df = pd.read_csv('data/enso_data.csv')

df
# Out:
#        datetime  Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  \
# 0    1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00
# 1    1982-02-01   25.49       -0.58  26.38       0.01  28.21       0.11
# 2    1982-03-01   25.21       -1.31  26.98      -0.16  28.41       0.22
# 3    1982-04-01   24.50       -0.97  27.68       0.18  28.92       0.42
# 4    1982-05-01   23.97       -0.23  27.79       0.71  29.49       0.70
# ..          ...     ...         ...    ...        ...    ...        ...
# 467  2020-12-01   22.16       -0.60  24.38      -0.83  27.65      -0.95
# 468  2021-01-01   23.89       -0.64  25.06      -0.55  27.10      -1.25
# 469  2021-02-01   25.55       -0.66  25.80      -0.57  27.20      -1.00
# 470  2021-03-01   26.48       -0.26  26.80      -0.39  27.79      -0.55
# 471  2021-04-01   24.89       -0.80  26.96      -0.65  28.47      -0.21
#
#      Nino34  Nino34anom
# 0     26.72        0.15
# 1     26.70       -0.02
# 2     27.20       -0.02
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=472, step=1)

# %% [markdown]
# This doesn't look ***exactly*** how we would like... since we want to index by the date

# %%
df = pd.read_csv('data/enso_data.csv', index_col=0, parse_dates=True)

# %%
df
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00   26.72
# 1982-02-01   25.49       -0.58  26.38       0.01  28.21       0.11   26.70
# 1982-03-01   25.21       -1.31  26.98      -0.16  28.41       0.22   27.20
# 1982-04-01   24.50       -0.97  27.68       0.18  28.92       0.42   28.02
# 1982-05-01   23.97       -0.23  27.79       0.71  29.49       0.70   28.54
# ...            ...         ...    ...        ...    ...        ...     ...
# 2020-12-01   22.16       -0.60  24.38      -0.83  27.65      -0.95   25.53
# 2021-01-01   23.89       -0.64  25.06      -0.55  27.10      -1.25   25.58
# 2021-02-01   25.55       -0.66  25.80      -0.57  27.20      -1.00   25.81
# 2021-03-01   26.48       -0.26  26.80      -0.39  27.79      -0.55   26.75
# 2021-04-01   24.89       -0.80  26.96      -0.65  28.47      -0.21   27.40
#
#             Nino34anom
# datetime
# ...

# %% [markdown]
# ## Taking a look at your data

# %%
# Take a look at first 5
df.head()
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00   26.72
# 1982-02-01   25.49       -0.58  26.38       0.01  28.21       0.11   26.70
# 1982-03-01   25.21       -1.31  26.98      -0.16  28.41       0.22   27.20
# 1982-04-01   24.50       -0.97  27.68       0.18  28.92       0.42   28.02
# 1982-05-01   23.97       -0.23  27.79       0.71  29.49       0.70   28.54
#
#             Nino34anom
# datetime
# 1982-01-01        0.15
# 1982-02-01       -0.02
# 1982-03-01       -0.02
# 1982-04-01        0.24
# 1982-05-01        0.69

# %%
# Last 5
df.tail()
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 2020-12-01   22.16       -0.60  24.38      -0.83  27.65      -0.95   25.53
# 2021-01-01   23.89       -0.64  25.06      -0.55  27.10      -1.25   25.58
# 2021-02-01   25.55       -0.66  25.80      -0.57  27.20      -1.00   25.81
# 2021-03-01   26.48       -0.26  26.80      -0.39  27.79      -0.55   26.75
# 2021-04-01   24.89       -0.80  26.96      -0.65  28.47      -0.21   27.40
#
#             Nino34anom
# datetime
# 2020-12-01       -1.12
# 2021-01-01       -0.99
# 2021-02-01       -0.92
# 2021-03-01       -0.51
# 2021-04-01       -0.49

# %%
df.columns
# Out:
# Index(['Nino12', 'Nino12anom', 'Nino3', 'Nino3anom', 'Nino4', 'Nino4anom',
#        'Nino34', 'Nino34anom'],
#       dtype='object')

# %%
# Summary Statistics
df.describe()
# Out:
#            Nino12  Nino12anom       Nino3   Nino3anom       Nino4   Nino4anom  \
# count  472.000000  472.000000  472.000000  472.000000  472.000000  472.000000
# mean    23.209619    0.059725   25.936568    0.039428   28.625064    0.063814
# std      2.431522    1.157590    1.349621    0.965464    0.755422    0.709401
# min     18.570000   -2.100000   23.030000   -2.070000   26.430000   -1.870000
# 25%     21.152500   -0.712500   24.850000   -0.600000   28.140000   -0.430000
# 50%     22.980000   -0.160000   25.885000   -0.115000   28.760000    0.205000
# 75%     25.322500    0.515000   26.962500    0.512500   29.190000    0.630000
# max     29.150000    4.620000   29.140000    3.620000   30.300000    1.670000
#
#            Nino34  Nino34anom
# count  472.000000  472.000000
# mean    27.076780    0.034894
# std      1.063004    0.947936
# min     24.270000   -2.380000
# 25%     26.330000   -0.572500
# 50%     27.100000    0.015000
# 75%     27.792500    0.565000
# ...

# %% [markdown]
# ## What's a Pandas Series?

# %%
df
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00   26.72
# 1982-02-01   25.49       -0.58  26.38       0.01  28.21       0.11   26.70
# 1982-03-01   25.21       -1.31  26.98      -0.16  28.41       0.22   27.20
# 1982-04-01   24.50       -0.97  27.68       0.18  28.92       0.42   28.02
# 1982-05-01   23.97       -0.23  27.79       0.71  29.49       0.70   28.54
# ...            ...         ...    ...        ...    ...        ...     ...
# 2020-12-01   22.16       -0.60  24.38      -0.83  27.65      -0.95   25.53
# 2021-01-01   23.89       -0.64  25.06      -0.55  27.10      -1.25   25.58
# 2021-02-01   25.55       -0.66  25.80      -0.57  27.20      -1.00   25.81
# 2021-03-01   26.48       -0.26  26.80      -0.39  27.79      -0.55   26.75
# 2021-04-01   24.89       -0.80  26.96      -0.65  28.47      -0.21   27.40
#
#             Nino34anom
# datetime
# ...

# %%
df['Nino34']
# Out:
# datetime
# 1982-01-01    26.72
# 1982-02-01    26.70
# 1982-03-01    27.20
# 1982-04-01    28.02
# 1982-05-01    28.54
#               ...
# 2020-12-01    25.53
# 2021-01-01    25.58
# 2021-02-01    25.81
# 2021-03-01    26.75
# 2021-04-01    27.40
# Name: Nino34, Length: 472, dtype: float64

# %%
df.sort_values('Nino34anom', ascending=False)
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 2015-11-01   23.83        2.24  27.91       2.93  30.30       1.67   29.60
# 2015-12-01   25.01        2.19  27.99       2.85  30.11       1.63   29.39
# 1983-01-01   27.42        2.96  28.92       3.29  29.00       0.70   29.36
# 1997-12-01   26.92        4.13  28.76       3.62  29.32       0.83   29.26
# 1997-11-01   25.63        4.04  28.55       3.57  29.49       0.86   29.32
# ...            ...         ...    ...        ...    ...        ...     ...
# 2000-01-01   23.86       -0.60  23.88      -1.75  26.96      -1.34   24.65
# 1989-01-01   24.09       -0.37  24.15      -1.48  26.54      -1.76   24.53
# 1988-10-01   19.50       -1.32  23.17      -1.75  27.06      -1.60   24.62
# 1988-12-01   21.80       -0.99  23.07      -2.07  26.75      -1.74   24.33
# 1988-11-01   20.55       -1.04  23.03      -1.95  26.76      -1.87   24.27
#
#             Nino34anom  Nino34_recalc_anom
# datetime
# ...

# %% [markdown]
# ## The Power of Pandas
#
# ### Quick Plots of Your Data

# %%
df.Nino12.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# ### Calculations

# %%
df.describe()
# Out:
#            Nino12  Nino12anom       Nino3   Nino3anom       Nino4   Nino4anom  \
# count  472.000000  472.000000  472.000000  472.000000  472.000000  472.000000
# mean    23.209619    0.059725   25.936568    0.039428   28.625064    0.063814
# std      2.431522    1.157590    1.349621    0.965464    0.755422    0.709401
# min     18.570000   -2.100000   23.030000   -2.070000   26.430000   -1.870000
# 25%     21.152500   -0.712500   24.850000   -0.600000   28.140000   -0.430000
# 50%     22.980000   -0.160000   25.885000   -0.115000   28.760000    0.205000
# 75%     25.322500    0.515000   26.962500    0.512500   29.190000    0.630000
# max     29.150000    4.620000   29.140000    3.620000   30.300000    1.670000
#
#            Nino34  Nino34anom  Nino34_recalc_anom
# count  472.000000  472.000000        4.720000e+02
# mean    27.076780    0.034894       -5.720471e-16
# std      1.063004    0.947936        1.063004e+00
# min     24.270000   -2.380000       -2.806780e+00
# ...

# %% [markdown]
# ### Slicing and Dicing

# %%
df[df.index.month == 1]
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00   26.72
# 1983-01-01   27.42        2.96  28.92       3.29  29.00       0.70   29.36
# 1984-01-01   24.18       -0.28  24.82      -0.81  27.64      -0.66   25.64
# 1985-01-01   23.59       -0.87  24.51      -1.12  27.71      -0.59   25.43
# 1986-01-01   24.61        0.15  24.73      -0.90  28.11      -0.19   25.79
# 1987-01-01   25.30        0.84  26.69       1.06  29.02       0.72   27.91
# 1988-01-01   24.64        0.18  26.12       0.49  29.13       0.83   27.32
# 1989-01-01   24.09       -0.37  24.15      -1.48  26.54      -1.76   24.53
# 1990-01-01   24.02       -0.44  25.34      -0.29  28.56       0.26   26.55
# 1991-01-01   23.86       -0.60  25.65       0.02  29.00       0.70   27.01
# 1992-01-01   24.83        0.37  27.00       1.37  29.06       0.76   28.41
# ...

# %%
df.loc[df.index.year == 1995]
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1995-01-01   25.33        0.87  26.34       0.71  29.20       0.90   27.55
# 1995-02-01   26.43        0.36  26.87       0.50  29.01       0.91   27.45
# 1995-03-01   26.12       -0.40  27.08      -0.06  28.96       0.77   27.63
# 1995-04-01   24.47       -1.00  27.10      -0.40  28.89       0.39   27.93
# 1995-05-01   23.10       -1.10  26.40      -0.68  29.15       0.36   27.73
# 1995-06-01   22.45       -0.37  26.20      -0.23  29.01       0.17   27.59
# 1995-07-01   21.23       -0.37  25.42      -0.20  28.78      -0.02   27.01
# 1995-08-01   20.01       -0.64  24.33      -0.66  28.43      -0.25   26.33
# 1995-09-01   20.17       -0.19  24.02      -0.83  28.25      -0.44   25.96
# 1995-10-01   20.15       -0.67  24.01      -0.91  28.07      -0.59   25.67
# 1995-11-01   21.20       -0.39  24.03      -0.95  27.97      -0.66   25.66
# ...

# %%
df[df.Nino34anom > 2]
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-11-01   24.59        3.00  27.62       2.64  29.23       0.60   28.81
# 1982-12-01   26.13        3.34  28.39       3.25  29.15       0.66   29.21
# 1983-01-01   27.42        2.96  28.92       3.29  29.00       0.70   29.36
# 1983-02-01   28.09        2.02  28.92       2.55  28.79       0.69   29.13
# 1997-08-01   24.80        4.15  27.84       2.85  29.26       0.58   28.84
# 1997-09-01   24.40        4.04  27.84       2.99  29.32       0.63   28.93
# 1997-10-01   24.58        3.76  28.17       3.25  29.32       0.66   29.23
# 1997-11-01   25.63        4.04  28.55       3.57  29.49       0.86   29.32
# 1997-12-01   26.92        4.13  28.76       3.62  29.32       0.83   29.26
# 1998-01-01   28.22        3.76  28.94       3.31  29.01       0.71   29.10
# 1998-02-01   28.98        2.91  28.93       2.56  28.87       0.77   28.86
# ...

# %% [markdown]
# ### Resampling

# %%
df.Nino34.resample('1Y').mean()
# Out:
# datetime
# 1982-12-31    28.060833
# 1983-12-31    27.553333
# 1984-12-31    26.365000
# 1985-12-31    26.335833
# 1986-12-31    27.155000
# 1987-12-31    28.367500
# 1988-12-31    25.935000
# 1989-12-31    26.226667
# 1990-12-31    27.190000
# 1991-12-31    27.680833
# 1992-12-31    27.687500
# 1993-12-31    27.410000
# 1994-12-31    27.443333
# 1995-12-31    26.840000
# 1996-12-31    26.559167
# 1997-12-31    28.285000
# 1998-12-31    26.894167
# 1999-12-31    25.856667
# 2000-12-31    26.149167
# 2001-12-31    26.786667
# 2002-12-31    27.775000
# 2003-12-31    27.340833
# 2004-12-31    27.421667
# 2005-12-31    27.157500
# 2006-12-31    27.209167
# 2007-12-31    26.513333
# 2008-12-31    26.303333
# 2009-12-31    27.412500
# 2010-12-31    26.585833
# 2011-12-31    26.208333
# 2012-12-31    27.022500
# 2013-12-31    26.816667
# 2014-12-31    27.272500
# 2015-12-31    28.619167
# 2016-12-31    27.423333
# 2017-12-31    26.953333
# 2018-12-31    27.130833
# 2019-12-31    27.588333
# ...

# %%
df.resample('1Y').mean()
# Out:
#                Nino12  Nino12anom      Nino3  Nino3anom      Nino4  Nino4anom  \
# datetime
# 1982-12-31  23.835833    0.723333  27.032500   1.145000  29.035833   0.480000
# 1983-12-31  25.593333    2.480833  27.010833   1.123333  28.495833  -0.060000
# 1984-12-31  22.674167   -0.438333  25.235833  -0.651667  27.893333  -0.662500
# 1985-12-31  22.054167   -1.058333  25.005000  -0.882500  28.063333  -0.492500
# 1986-12-31  22.929167   -0.183333  25.908333   0.020833  28.727500   0.171667
# 1987-12-31  24.309167    1.196667  27.118333   1.230833  29.351667   0.795833
# 1988-12-31  22.165833   -0.946667  24.681667  -1.205833  27.868333  -0.687500
# 1989-12-31  22.746667   -0.365833  25.245833  -0.641667  27.786667  -0.769167
# 1990-12-31  22.746667   -0.365833  25.864167  -0.023333  28.950833   0.395000
# 1991-12-31  23.280833    0.168333  26.361667   0.474167  29.192500   0.636667
# 1992-12-31  23.702500    0.590000  26.331667   0.444167  29.045000   0.489167
# ...

# %%
df.groupby?
# Out:
#             Nino12  Nino12anom  Nino3  Nino3anom  Nino4  Nino4anom  Nino34  \
# datetime
# 1982-01-01   24.29       -0.17  25.87       0.24  28.30       0.00   26.72
# 1982-02-01   25.49       -0.58  26.38       0.01  28.21       0.11   26.70
# 1982-03-01   25.21       -1.31  26.98      -0.16  28.41       0.22   27.20
# 1982-04-01   24.50       -0.97  27.68       0.18  28.92       0.42   28.02
# 1982-05-01   23.97       -0.23  27.79       0.71  29.49       0.70   28.54
# ...            ...         ...    ...        ...    ...        ...     ...
# 2020-12-01   22.16       -0.60  24.38      -0.83  27.65      -0.95   25.53
# 2021-01-01   23.89       -0.64  25.06      -0.55  27.10      -1.25   25.58
# 2021-02-01   25.55       -0.66  25.80      -0.57  27.20      -1.00   25.81
# 2021-03-01   26.48       -0.26  26.80      -0.39  27.79      -0.55   26.75
# 2021-04-01   24.89       -0.80  26.96      -0.65  28.47      -0.21   27.40
#
#             Nino34anom
# datetime
# ...

# %%
temp_cols = []
anom_cols = []

for column in df.columns:
    if 'anom' in column:
        anom_cols.append(column)
        
    else:
        temp_cols.append(column)

# %%
df[temp_cols].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
df[anom_cols].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
